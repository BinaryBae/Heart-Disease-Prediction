# %%
# !pip install sdv

# %%
import pandas as pd
from sdv.metadata import SingleTableMetadata

# %%
real_data = pd.read_csv("/kaggle/input/heart-disease-cleveland/Heart_disease_cleveland_new.csv")
real_data['id'] = range(1, len(real_data) + 1)
real_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target  id
# 0   0     2       0   1
# 1   3     1       1   2
# 2   2     3       1   3
# 3   0     1       0   4
# 4   0     1       0   5

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(real_data)
metadata.validate_data(data=real_data)
metadata.set_primary_key(column_name='id')
print(metadata)
# Out:
# {
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1",
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "sex": {
#             "sdtype": "categorical"
#         },
#         "cp": {
#             "sdtype": "categorical"
#         },
#         "trestbps": {
#             "sdtype": "numerical"
#         },
#         "chol": {
#             "sdtype": "numerical"
#         },
#         "fbs": {
#             "sdtype": "categorical"
#         },
#         "restecg": {
#             "sdtype": "categorical"
#         },
#         "thalach": {
#             "sdtype": "numerical"
#         },
#         "exang": {
#             "sdtype": "categorical"
#         },
#         "oldpeak": {
#             "sdtype": "numerical"
#         },
#         "slope": {
#             "sdtype": "categorical"
#         },
#         "ca": {
#             "sdtype": "categorical"
#         },
#         "thal": {
#             "sdtype": "categorical"
#         },
# ...

# %%
from sdv.single_table import GaussianCopulaSynthesizer
synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(real_data)
synthetic_data = synthesizer.sample(num_rows=1000)
synthetic_data.head(10)
synthetic_data = synthetic_data.drop('id',axis=1)
synthetic_data.to_csv('GaussianCopulaSynthesizer_dataset.csv',index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/sdv/single_table/base.py:80: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(

# %%
from sdv.single_table import CTGANSynthesizer

synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(real_data)

synthetic_data = synthesizer.sample(num_rows=1000)
synthetic_data = synthetic_data.drop('id',axis=1)
synthetic_data.to_csv('CTGANSynthesizer_dataset.csv',index=False)

# %%
from sdv.single_table import TVAESynthesizer

synthesizer = TVAESynthesizer(metadata)
synthesizer.fit(real_data)

synthetic_data = synthesizer.sample(num_rows=1000)
synthetic_data = synthetic_data.drop('id',axis=1)
synthetic_data.to_csv('TVAESynthesizer_dataset.csv',index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/ctgan/data_transformer.py:196: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.62273787e-01  7.96643050e-02 -5.71985133e-02 -2.27381362e-01
#  -3.50335156e-01  1.71944857e-01  1.68077855e-01  7.97412725e-02
#   2.49457540e-01 -8.54195707e-02 -7.82905592e-02  5.16058264e-01
#  -5.55411457e-02  1.05715726e-02  4.31416686e-01  1.91287903e-01
#  -1.22071680e-01 -6.17087485e-02 -1.93241603e-01 -2.18535788e-01
#   3.31806128e-01 -1.66581064e-01  5.20558827e-01 -4.13185887e-03
#  -2.07924677e-01  4.01590583e-02  1.32569437e-01  3.61803114e-01
#   2.64460736e-02 -1.00645951e-01  4.30272403e-01 -1.83547074e-03
#  -9.46060842e-02 -1.38978335e-01 -2.93211308e-01  2.16661598e-01
#   2.01217752e-01 -5.81979753e-02 -3.63074705e-01  1.18785774e-02
#  -7.67917218e-02 -1.66396152e-02  6.99401241e-02  2.62601711e-01
#   1.14596835e-01 -5.45188551e-02 -2.13054296e-01 -2.60522853e-02
# ...

# %%
from sdv.single_table import CopulaGANSynthesizer

synthesizer = CopulaGANSynthesizer(metadata)
synthesizer.fit(real_data)

synthetic_data = synthesizer.sample(num_rows=1000)
synthetic_data = synthetic_data.drop('id',axis=1)
synthetic_data.to_csv('CopulaGANSynthesizer_dataset.csv',index=False)
